# %% [markdown]
# # websocket-client

# %%
import websocket

# %%
def on_message(ws, message):
    #print("WebSocketHandler: Message Handler")

    # this is potentially dangerous
    print(message)

# %%
ws = websocket.WebSocketApp(
    'ws://{}:{}'.format("10.1.24.7", 2459),
    subprotocols=['isaac-json-protocol'],
    on_message=on_message)
ws.run_forever()

# %% [markdown]
# # websockets

# %%
import websockets.asyncio.client as websocket

# %%
async with websocket.connect(
    f'ws://{"10.1.24.7"}:{2459}',
    subprotocols=['isaac-json-protocol'],
) as ws:
    async for message in ws:
        print(f"Received: {message}")
# Out:
# Received: {"type": "hello", "name": "ISAAC Visualization server", "streams": [{"name": "JPEG_URI_Stream", "id": 0}]}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 async with websocket.connect(
#       2     f'ws://{"10.1.24.7"}:{2459}',
#       3     subprotocols=['isaac-json-protocol'],
#       4 ) as ws:
# ----> 5     async for message in ws:
#       6         print(f"Received: {message}")
#
# File ~/src/miniforge3/envs/isaac-client/lib/python3.13/site-packages/websockets/asyncio/connection.py:237, in Connection.__aiter__(self)
#     235 try:
#     236     while True:
# --> 237         yield await self.recv()
#     238 except ConnectionClosedOK:
#     239     return
#
# File ~/src/miniforge3/envs/isaac-client/lib/python3.13/site-packages/websockets/asyncio/connection.py:298, in Connection.recv(self, decode)
#     251 """
#     252 Receive the next message.
#     253
#    (...)    295
#     296 """
#     297 try:
# --> 298     return await self.recv_messages.get(decode)
#     299 except EOFError:
#     300     pass
#
# File ~/src/miniforge3/envs/isaac-client/lib/python3.13/site-packages/websockets/asyncio/messages.py:158, in Assembler.get(self, decode)
#     153 # Locking with get_in_progress prevents concurrent execution
#     154 # until get() fetches a complete message or is canceled.
#     156 try:
#     157     # Fetch the first frame.
# --> 158     frame = await self.frames.get(not self.closed)
#     159     self.maybe_resume()
#     160     assert frame.opcode is TEXT or frame.opcode is BINARY
#
# File ~/src/miniforge3/envs/isaac-client/lib/python3.13/site-packages/websockets/asyncio/messages.py:51, in SimpleQueue.get(self, block)
#      49 self.get_waiter = self.loop.create_future()
#      50 try:
# ---> 51     await self.get_waiter
#      52 finally:
#      53     self.get_waiter.cancel()
#
# CancelledError:
